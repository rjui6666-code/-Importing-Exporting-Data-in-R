# %% [markdown]
# <a href="https://colab.research.google.com/github/rjui6666-code/-Importing-Exporting-Data-in-R/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Class 3 homework

# %%
def sum_to_n(n):
    total = 0
    for i in range(1, n + 1):
        total += i
    return total

# user input
n = int(input("Enter a number: "))

result = sum_to_n(n)
print("Sum from 1 to", n, "is:", result)

# %%
result = square(5)
print(result)

# %%
def is_even(n):
    return n % 2 == 0

num = int(input("5:"))

if is_even(num):
    print("The number is Even")
else:
    print("The number is Odd")

# %%
result = larger_number(10, 25)
print(result)
